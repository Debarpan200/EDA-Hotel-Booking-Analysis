# %% [markdown]
# # **Project Name** - Booking.com - Hotel Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA (Exploratory Data Analysis)
# ##### **Contribution**    - Individual (Debarpan Chowdhury)

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This analysis delved into a comprehensive dataset of 119,390 hotel bookings, aiming to uncover insights into customer behavior and booking patterns. The dataset encompassed a wide range of variables, including booking details, customer demographics, room preferences, and cancellation information.
#
# Before diving into the analysis, the dataset underwent a rigorous cleaning process. Duplicate records were eliminated, Corrected improper data type format which was used in the data, and missing values were addressed. The 'country', 'children', and 'agent' variables were imputed with their respective modes, while the 'company' variable, due to its high percentage of missing values, was dropped.
#
# The EDA phase involved a combination of statistical analysis and data visualization techniques:
#
# * Descriptive Statistics:
# Key metrics such as mean, median, mode, standard deviation, and quartiles were calculated for numerical variables.
#
# * Data Visualization:
# 1. Bar Plots: Compared categorical variables against numerical variables to identify trends.
# 2. Heatmaps: Visualized the correlation matrix to understand the relationships between numerical variables.
# 3. Pair Plots: Explored pairwise relationships between some numerical variables.
# 4. Line Plots + Scatter Plot: line plots are used in showing the trands/count over time period and Scatterplot is used in specifing the data points.
#
# Main Libraries to be used:
#
# 1. Pandas for data manipulation, aggregation
# 2. Matplotlib and Seaborn for visualisation and behaviour with respect to the target variable.
# 3. NumPy for computationally efficient operations

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# GitHub Link - https://github.com/Debarpan200/EDA-Hotel-Booking-Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Explore and analyze the data to discover important factors that govern the bookings.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Our primary goal is to conduct EDA on the provided dataset and derive valuable conclusions about broad hotel booking trends and how various factors interact to affect hotel bookings.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# # **Solution:**

# %% [markdown]
# ## **Importing Libraries to be used**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Reading CSV file**

# %%
read_hotel_booking = pd.read_csv("Hotel Bookings.csv")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## **Analyzing Data**

# %%
read_hotel_booking.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
read_hotel_booking.shape
# Out:
# (119390, 32)

# %%
read_hotel_booking.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
read_hotel_booking.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
read_hotel_booking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# ## **Total number of not null values in those columns which have null values inside it [As shown in info() function]**

# %%
read_hotel_booking["children"].count()
# Out:
# np.int64(119386)

# %%
read_hotel_booking["country"].count()
# Out:
# np.int64(118902)

# %%
read_hotel_booking["company"].count()
# Out:
# np.int64(6797)

# %%
read_hotel_booking["agent"].count()
# Out:
# np.int64(103050)

# %% [markdown]
# ## **ploting the dataframe in the heatmap to visualize total count of null values in each column**

# %%
sns.heatmap(read_hotel_booking.isna())
plt.show()

# %%
read_hotel_booking.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# ## **Total number of isnull count in the specific column which contain null values**

# %%
read_hotel_booking['children'].isnull().sum()
# Out:
# np.int64(4)

# %%
read_hotel_booking['country'].isnull().sum()
# Out:
# np.int64(488)

# %%
read_hotel_booking.dropna(subset=['country'], inplace=True)

# %%
read_hotel_booking['country'].isnull().sum()
# Out:
# np.int64(0)

# %%
read_hotel_booking.shape
# Out:
# (118902, 32)

# %% [markdown]
# **Because in the company column maximum rows are filled with null values so we can drop the column because from this column I would not be able to get any insights**

# %%
read_hotel_booking.drop('company', axis=1, inplace=True)

# %%
read_hotel_booking['agent'].isnull().sum()
# Out:
# np.int64(16006)

# %% [markdown]
# ## **Replacing null values**

# %% [markdown]
# ### **Children**

# %%
read_hotel_booking['children'].astype(float).mean().__round__(0)
# Out:
# np.float64(0.0)

# %%
# replace missing values children column with mean value
read_hotel_booking['children'].fillna((read_hotel_booking['children'].astype(float).mean().__round__(0)), inplace=True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_13512\2425113096.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   read_hotel_booking['children'].fillna((read_hotel_booking['children'].astype(float).mean().__round__(0)), inplace=True)

# %%
read_hotel_booking['children'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### **agent**

# %%
read_hotel_booking['agent'].value_counts()
# Out:
# agent
# 9.0      31960
# 240.0    13871
# 1.0       7191
# 14.0      3639
# 7.0       3539
# 6.0       3283
# 250.0     2855
# 241.0     1718
# 28.0      1666
# 8.0       1514
# 3.0       1336
# 37.0      1229
# 19.0      1061
# 40.0      1039
# 314.0      920
# 21.0       875
# 229.0      786
# 242.0      779
# 83.0       696
# 29.0       683
# 171.0      605
# 12.0       564
# 85.0       554
# 20.0       540
# 96.0       525
# 243.0      514
# 30.0       484
# 134.0      482
# 298.0      472
# 27.0       450
# 15.0       401
# 26.0       401
# 11.0       395
# 22.0       382
# 56.0       375
# 273.0      349
# 177.0      345
# 86.0       338
# 58.0       335
# 5.0        329
# 119.0      304
# 196.0      298
# 34.0       294
# 44.0       292
# 138.0      287
# 315.0      284
# 38.0       274
# 10.0       260
# 236.0      247
# 16.0       246
# 17.0       241
# 115.0      225
# 251.0      220
# 68.0       211
# 42.0       211
# 191.0      198
# 175.0      194
# 195.0      193
# ...

# %%
# replace missing values agent column with mean value
read_hotel_booking['agent'].fillna(9.0, inplace=True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_13512\652053373.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   read_hotel_booking['agent'].fillna(9.0, inplace=True)

# %%
read_hotel_booking['agent'].isnull().sum()
# Out:
# np.int64(0)

# %%
read_hotel_booking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 118902 entries, 0 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           118902 non-null  object
#  1   is_canceled                     118902 non-null  int64
#  2   lead_time                       118902 non-null  int64
#  3   arrival_date_year               118902 non-null  int64
#  4   arrival_date_month              118902 non-null  object
#  5   arrival_date_week_number        118902 non-null  int64
#  6   arrival_date_day_of_month       118902 non-null  int64
#  7   stays_in_weekend_nights         118902 non-null  int64
#  8   stays_in_week_nights            118902 non-null  int64
#  9   adults                          118902 non-null  int64
#  10  children                        118902 non-null  float64
#  11  babies                          118902 non-null  int64
# ...

# %%
read_hotel_booking.shape
# Out:
# (118902, 31)

# %% [markdown]
# ## **Correcting Data Type of the Column**

# %%
read_hotel_booking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 118902 entries, 0 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           118902 non-null  object
#  1   is_canceled                     118902 non-null  int64
#  2   lead_time                       118902 non-null  int64
#  3   arrival_date_year               118902 non-null  int64
#  4   arrival_date_month              118902 non-null  object
#  5   arrival_date_week_number        118902 non-null  int64
#  6   arrival_date_day_of_month       118902 non-null  int64
#  7   stays_in_weekend_nights         118902 non-null  int64
#  8   stays_in_week_nights            118902 non-null  int64
#  9   adults                          118902 non-null  int64
#  10  children                        118902 non-null  float64
#  11  babies                          118902 non-null  int64
# ...

# %%
read_hotel_booking[['children','agent','reservation_status_date']].dtypes
# Out:
# children                   float64
# agent                      float64
# reservation_status_date     object
# dtype: object

# %%
# Change datatype of variables children and agent to correct format from float64 to int64
read_hotel_booking[['children','agent']]=read_hotel_booking[['children','agent']].astype('int64')

# Change datatype of variable reservation_status_date to correct format from object to datetime64
read_hotel_booking['reservation_status_date']=pd.to_datetime(read_hotel_booking['reservation_status_date'], format='%Y-%m-%d')

# %%
# Checking datatype
read_hotel_booking[['children','agent','reservation_status_date']].dtypes
# Out:
# children                            int64
# agent                               int64
# reservation_status_date    datetime64[ns]
# dtype: object

# %% [markdown]
# ## **Removing Duplicate Rows in the Dataframe if there is any duplicate rows available**

# %%
read_hotel_booking.shape
# Out:
# (118902, 31)

# %%
read_hotel_booking.drop_duplicates(inplace=True)

# %%
read_hotel_booking.shape
# Out:
# (86936, 31)

# %%
read_hotel_booking.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  86936.000000  86936.000000       86936.000000
# mean       0.275962     80.196627        2016.211776
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     12.000000        2016.000000
# 50%        0.000000     50.000000        2016.000000
# 75%        1.000000    125.000000        2017.000000
# max        1.000000    737.000000        2017.000000
# std        0.447000     86.100763           0.686040
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              86936.000000               86936.000000
# mean                  26.841274                  15.817739
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   37.000000                  23.000000
# max                   53.000000                  31.000000
# ...

# %% [markdown]
# ## **Let's Start Visualizing**

# %% [markdown]
# ### **Question 1:** What are the total number of hotel booked Yearly?

# %%
data_yearly = read_hotel_booking['arrival_date_year'].value_counts(sort=True)

# %%
sns.barplot(x=data_yearly.index, y=data_yearly.values, hue=data_yearly.index)
plt.title('Total Hotel Booking Yearly')
plt.xlabel('Years')
plt.ylabel('Booking')
plt.show()

# %% [markdown]
# The maximum booking Yearly is in 2016 with approx 40000 bookings as per the DataSet

# %% [markdown]
# ### **Question 2:** Total Monthly Booking of 2015, 2016 & 2017?

# %%
desired_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# %% [markdown]
# #### Monthly Booking in 2015

# %%
df_2015 = read_hotel_booking[read_hotel_booking['arrival_date_year'] == 2015]

# Count the number of bookings for each month in 2015
month_counts = df_2015['arrival_date_month'].value_counts().reindex(desired_order).dropna()

print(month_counts)
# Out:
# arrival_date_month
# July         1661.0
# August       2441.0
# September    2819.0
# October      2676.0
# November     1643.0
# December     1962.0
# Name: count, dtype: float64

# %%
sns.lineplot(x=month_counts.index, y=month_counts.values)
sns.scatterplot(x=month_counts.index, y=month_counts.values)
plt.title('Total Hotel Booking Monthly in 2015')
plt.xlabel('Month')
plt.ylabel('Booking')
plt.ylim(1600)
plt.show()

# %% [markdown]
# In 2015 from July till December -
# * Maximum number of booking is in September with approx 2800 bookings
# * Minimum number of booking in July & Novemver with Approx 1600 bookings.

# %% [markdown]
# #### Monthly Booking in 2016

# %%
df_2016 = read_hotel_booking[read_hotel_booking['arrival_date_year'] == 2016]


month_counts_1 = df_2016['arrival_date_month'].value_counts().reindex(desired_order)

# %%
sns.lineplot(x=month_counts_1.index, y=month_counts_1.values)
sns.scatterplot(x=month_counts_1.index, y=month_counts_1.values)
plt.title('Total Hotel Booking Monthly in 2016')
plt.xlabel('Month')
plt.ylabel('Booking')
plt.xticks(rotation=90)
plt.ylim(1500)
plt.show()

# %% [markdown]
# In 2016 -
# * Maximum number of booking is in August with approx 4400 bookings
# * Minimum number of booking in January with Approx 1800 bookings.

# %% [markdown]
# #### Monthly Booking in 2017

# %%
df_2017 = read_hotel_booking[read_hotel_booking['arrival_date_year'] == 2017]

# Count the number of bookings for each month in 2015
month_counts_2 = df_2017['arrival_date_month'].value_counts().reindex(desired_order).dropna()

# %%
sns.lineplot(x=month_counts_2.index, y=month_counts_2.values)
sns.scatterplot(x=month_counts_2.index, y=month_counts_2.values)
plt.title('Total Hotel Booking Monthly in 2017')
plt.xlabel('Month')
plt.ylabel('Booking')
plt.ylim(2750)
plt.show()

# %% [markdown]
# In 2017 from January till August -
# * Maximum number of booking is in May with approx 4500 bookings
# * Minimum number of booking in July & Novemver with Approx 2800 bookings.

# %% [markdown]
# ### **Question 3:** Which Type of Customer Booked Maximum Hotels

# %%
data = read_hotel_booking['customer_type'].value_counts()

# %%
sns.barplot(x=data.index, y=data.values, hue=data.index)
plt.title('Types of Customer Books Maximum number of Hotels')
plt.xlabel('Customer Type')
plt.ylabel('Booking')
plt.show()

# %% [markdown]
# The type of customer who booked maximum number of booking - Transient with Approx 70000

# %% [markdown]
# #### **Question 4:** Which Top Country Makes the most reservation?

# %%
country_count = read_hotel_booking['country'].value_counts().head(10)

# %%
sns.barplot(x=country_count.index, y=country_count.values, hue=country_count.index)
plt.title('Which Country Makes The Maximum Booking')
plt.xlabel('Customer Type')
plt.ylabel('Booking')
plt.show()

# %% [markdown]
# The majority of reservations are made through country PRT. Customers make the most bookings in the following top 5 countries: PRT, GBR, FRA, ESP, and DEU.

# %% [markdown]
# ### **Question 5:** Which Hotel type is the Busiest?

# %%
hotel_column = read_hotel_booking['hotel']
waiting_list_column = read_hotel_booking['days_in_waiting_list']
sns.barplot(x=hotel_column, y=waiting_list_column, errorbar=None, hue=hotel_column)
plt.title('Which hotel Type has the maximum waiting period')
plt.show()

# %% [markdown]
# A city hotel is busier than a resort.

# %% [markdown]
# ### **Question 6:** Total number of reservation canceled in each type of Hotel?

# %%
df_ResortHotel = read_hotel_booking[read_hotel_booking['hotel'] == 'Resort Hotel']

Resort_cancel_counts = (df_ResortHotel['is_canceled'] == 1).sum()

print('Total number of Resort Hotel Booking Canceled:',Resort_cancel_counts)
# Out:
# Total number of Resort Hotel Booking Canceled: 7946

# %%
df_CityHotel = read_hotel_booking[read_hotel_booking['hotel'] == 'City Hotel']

City_cancel_counts = (df_CityHotel['is_canceled'] == 1).sum()

print('Total number of City Hotel Booking Canceled:',City_cancel_counts)
# Out:
# Total number of City Hotel Booking Canceled: 16045

# %%
hotel_types = ['Resort Hotel', 'City Hotel']
cancel_counts = [Resort_cancel_counts, City_cancel_counts]

# %%
sns.barplot(x = hotel_types, y = cancel_counts, hue=hotel_types)
plt.xlabel('Hotel Type')
plt.ylabel('Number of Cancellations')
plt.title('Hotel Booking Cancellations by Type of Hotel')
plt.show()

# %% [markdown]
# City Hotel have maximum number of booking cancelled in the DataSet

# %% [markdown]
# #### **Qeestion 7:** Which Market Segment has maximum and Minimum number of booking.

# %%
market_segment = read_hotel_booking['market_segment'].value_counts()

# %%
sns.barplot(x = market_segment.index, y = market_segment.values, hue=market_segment.index)
plt.xlabel('Market Segments')
plt.ylabel('Bookings')
plt.title('Market Segment wise Maximum and Minimum Booking')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Market Segment wise Online TA have maximum number of Booking and Aviation have approximately Minimum number of booking

# %% [markdown]
# #### **Question 8:** Top 10 agent makes the most number of booking.

# %%
top_10_agents = read_hotel_booking['agent'].value_counts().head(10)

sns.barplot(x= top_10_agents.index, y= top_10_agents.values)
plt.xlabel('Agent')
plt.ylabel('Number of Bookings')
plt.title('Top 10 Agents by Number of Bookings')
plt.show()

# %% [markdown]
# Agent number 9 made most number of bookings. 9, 240, 7, 14 and 250 are the top 5 agents by number of bookings made.

# %% [markdown]
# ### **Question 9:** How many customer don't wish to make a booking with a pre-deposit.

# %%
deposit_df = read_hotel_booking['deposit_type'].value_counts()

# %%
sns.barplot(x= deposit_df.index, y= deposit_df.values, hue=deposit_df.index)
plt.xlabel('Deposit Type')
plt.ylabel('Number of Booking')
plt.title("Booking with no pre-deposit")
plt.show()

# %% [markdown]
# Customers do not wish to make a bookings with a pre-deposit.

# %% [markdown]
# ### **Question 10:** Number of Repeted Guest

# %%
repeated_guest = read_hotel_booking['is_repeated_guest'].value_counts()

# %%
sns.barplot(x=repeated_guest.index, y=repeated_guest.values, hue=repeated_guest)
plt.ylabel('Booking')
plt.show()

# %% [markdown]
# Only 3400 guest are repeated which is less then 5%

# %% [markdown]
# #### **Question 11:** Correlation Heatmap

# %%
new_df = read_hotel_booking[['lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'previous_cancellations', 
                                'previous_bookings_not_canceled', 'booking_changes', 'days_in_waiting_list', 'adr', 'required_car_parking_spaces', 
                                'total_of_special_requests']]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(new_df.corr(), vmin=-1, cmap='coolwarm', annot=True)
plt.show()

# %% [markdown]
# * Guests often book multiple nights, especially for weekends.
# * Longer lead times can result in longer wait times.
# * Guests with more special requests are less likely to need parking.
# * Bookings with more adults tend to have higher rates.
# * Guests who make more changes might have shorter wait times.

# %% [markdown]
# #### **Question 12:** Pair Plots

# %% [markdown]
# ##### **Guest vs. Booking Length**

# %%
df_pair_plot1 = read_hotel_booking[['adults', 'children', 'babies', 'stays_in_weekend_nights', 'stays_in_week_nights']]

# %%
plt.figure()
sns.pairplot(df_pair_plot1)
plt.show()

# %% [markdown]
# * Guests often book multiple nights, both on weekends and weekdays.
# * that bookings with more adults often include children as well.

# %% [markdown]
# ## **Solution to Business Objective**

# %% [markdown]
# * A city hotel has more bookings than a resort. Offer packages and promotions to promote bookings for the resort hotel.
# * Most of the bookings are made through the online platform. Hotels can cut costs by eliminating market segments such as complementary and aviation because bookings through these segments are very low.
# * Minimize the impact of the city hotel cancellation and provide a satisfactory alternative at a resort hotel if needed.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# * The top country with the most number of bookings is PRT.
# * The number one agent with the most number of bookings is 9.
# * The Maximum hotel bookings are made by new guests. Only less then 5% guests returned.
# * The Online (internet) platform is used to make the majority of bookings.
# * A city hotel is busier than a resort.
# * The busiest months for hotels are August, September and October.
# * Customers do not wish to make a bookings with a pre-deposit.

# %% [markdown]
# # **Challenges Faced**

# %% [markdown]
# * The data contained a large number of duplicates.
# * It was challenging to select the best visualization techniques.
# * The dataset contained a large number of null values.
# * The improper data type format was used for the data.
